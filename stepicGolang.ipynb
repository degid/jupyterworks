# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('stepicGolang-09-09-2020.csv', sep=';')

# %%
df.head()
# Out:
#    task  students
# 0     1      5036
# 1     2      4968
# 2     3      4347
# 3     4      4025
# 4     5      3517

# %%
df['students'].hist();

# %%
df.hist();

# %%
from scipy.stats import spearmanr

# %% [markdown]
# ### Соотношение номера задания и количества стедентов

# %%
sns.jointplot(x='task', y='students', data=df);

# %% [markdown]
# #### Статистика

# %%
df['students'].describe()
# Out:
# count     145.000000
# mean     1031.013793
# std      1004.644112
# min       131.000000
# 25%       348.000000
# 50%       688.000000
# 75%      1340.000000
# max      5036.000000
# Name: students, dtype: float64

# %% [markdown]
# **Поступивших на курс:** {{int(df['students'].describe().max())}}
# **Окончившие курс:** {{int(df['students'].describe().min())}}
# **В процессе прохождения:** {{int(df['students'].describe().max() - df['students'].describe().min())}}

# %%
sns.regplot(x="task", y="students", data=df);

# %%
sns.kdeplot(df['students'])
sns.rugplot(df['students']);

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   task      145 non-null    int64
#  1   students  145 non-null    int64
# dtypes: int64(2)
# memory usage: 2.4 KB
